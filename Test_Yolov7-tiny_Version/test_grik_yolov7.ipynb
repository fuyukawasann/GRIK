# %% [markdown]
# # GRIK Project Using YOLOv7

# %% [markdown]
# ## YOLOv7 환경설정

# %% [markdown]
# ### YOLOv7 다운로드

# %%
## 설치
import sys
import torch
print(f"Python version: {sys.version}, {sys.version_info}")
print(f"Pytorch version: {torch.__version__}")
# Out:
# Python version: 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], sys.version_info(major=3, minor=11, micro=2, releaselevel='final', serial=0)
# Pytorch version: 2.2.1+cu121

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\wmp91\Desktop\졸작\GRIK\Test_Yolov7-tiny_Version

# %%
# YOLOv7 다운로드
# !git clone https://github.com/WongKinYiu/yolov7.git
# %cd yolov7
# Out:
# c:\Users\wmp91\Desktop\졸작\GRIK\Test_Yolov7-tiny_Version\yolov7
# fatal: destination path 'yolov7' already exists and is not an empty directory.
# C:\Users\wmp91\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
## 패키지 설치
# !pip3 install -r requirements.txt

# %% [markdown]
# ### 데이터 옮기기

# %%
import os
print(os.path.realpath('.'))
# Out:
# C:\Users\wmp91\Desktop\졸작\GRIK\Test_Yolov7-tiny_Version\yolov7

# %%
import platform
if(platform.system() == 'Windows'): # Windows
    import shutil
    file_name = "../GRIKDataset.zip"
    output_dir = "data/"
    format = "zip"
    shutil.unpack_archive(file_name, output_dir, format)
else: # macOS, Linux
    # !pwd
    # !unzip -uq "../GRIKDataset.zip" -d "data/"

# %% [markdown]
# ### 가중치 파일 받기

# %%
import sys
import subprocess

if(platform.system() == 'Windows'): # Windows
    print(os.path.realpath('.'))
else: # macOS, Linux
    # !pwd

try:
	import wget
except:
    # pip 모듈 업그레이드
    subprocess.check_call([sys.executable,'-m', 'pip', 'install', '--upgrade', 'pip'])
    # 에러 발생한 모듈 설치
    subprocess.check_call([sys.executable,'-m', 'pip', 'install', '--upgrade', 'wget'])
    import wget

select_model = input("어떤 모델로 학습할까요? 1: yolov7  2: yolov7-tiny  >")
if select_model == '1':
    wget.download("https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt")
elif select_model == '2':
    wget.download("https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-tiny.pt")
else:
    print("잘못된 입력입니다.")
    sys.exit(1)
# Out:
# C:\Users\wmp91\Desktop\졸작\GRIK\Test_Yolov7-tiny_Version\yolov7

# %% [markdown]
# ## 학습 시작

# %% [markdown]
# ### YOLOv7

# %%
# 현재 경로 확인
if(platform.system() == 'Windows'): # Windows
    print(os.path.realpath('.'))
else: # macOS, Linux
    # !pwd
    
# 학습 시작
if(torch.backends.mps.is_available()):
	# !python train.py --workers 1 --device mps --batch-size 8 --epochs 100 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --name yolov7-custom --weights yolov7.pt
elif(torch.cuda.is_available()):
    # !python train.py --workers 1 --device 0 --batch-size 8 --epochs 100 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --name yolov7-custom --weights yolov7.pt
else:
    # !python train.py --workers 1 --batch-size 8 --epochs 100 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --name yolov7-custom --weights yolov7.pt
# Out:
# C:\Users\wmp91\Desktop\졸작\GRIK\Test_Yolov7-tiny_Version\yolov7
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
# autoanchor: Analyzing anchors... anchors/target = 5.10, Best Possible Recall (BPR) = 1.0000
#                  all          20          50      0.0143        0.12     0.00252    0.000505
#                  all          20          50     0.00589        0.06     0.00214     0.00026
#                  all          20          50     0.00642        0.28     0.00354    0.000548
#                  all          20          50      0.0176        0.22     0.00749     0.00157
#                  all          20          50      0.0792        0.08      0.0215     0.00498
#                  all          20          50       0.204        0.26       0.113      0.0194
#                  all          20          50       0.192        0.26      0.0844      0.0167
# ...

# %% [markdown]
# ### YOLOv7-tiny

# %%
# 현재 경로 확인
if(platform.system() == 'Windows'): # Windows
    print(os.path.realpath('.'))
else: # macOS, Linux
    # !pwd
    
# 학습 시작
if(torch.backends.mps.is_available()):
	# !python train.py --workers 1 --device mps --batch-size 8 --epochs 100 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --name yolov7-tiny-custom --weights yolov7-tiny.pt
elif(torch.cuda.is_available()):
    # !python train.py --workers 1 --device 0 --batch-size 8 --epochs 100 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --name yolov7-tiny-custom --weights yolov7-tiny.pt
else:
    # !python train.py --workers 1 --batch-size 8 --epochs 100 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --name yolov7-tiny-custom --weights yolov7-tiny.pt

# %% [markdown]
# ## 테스트

# %%
if(torch.backends.mps.is_available()):
	# !python detect.py --weights ./runs/train/yolov7-custom/weights/best.pt --device mps --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
elif(torch.cuda.is_available()):
    # !python detect.py --weights ./runs/train/yolov7-custom/weights/best.pt --device 0 --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
else:
    # !python detect.py --weights ./runs/train/yolov7-custom/weights/best.pt --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
# Out:
# Namespace(weights=['./runs/train/yolov7-custom/weights/best.pt'], source='../Test_IMG/test05.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='0', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 3 panseos, Done. (10.5ms) Inference, (76.1ms) NMS
#  The image with the result is saved in: runs\detect\exp\test05.jpg
# Done. (0.385s)
# YOLOR  v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
#
# ...
