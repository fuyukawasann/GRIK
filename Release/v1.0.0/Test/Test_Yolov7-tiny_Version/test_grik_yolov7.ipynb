# %% [markdown]
# # GRIK Project Using YOLOv7

# %% [markdown]
# ## YOLOv7 환경설정

# %% [markdown]
# ### YOLOv7 다운로드

# %%
## 설치
import sys
import torch
print(f"Python version: {sys.version}, {sys.version_info}")
print(f"Pytorch version: {torch.__version__}")
# Out:
# Python version: 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], sys.version_info(major=3, minor=11, micro=2, releaselevel='final', serial=0)
# Pytorch version: 2.2.1+cu121

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\wmp91\Desktop\졸작\GRIK\test\Test_Yolov7-tiny_Version

# %%
# YOLOv7 다운로드
# !git clone https://github.com/WongKinYiu/yolov7.git
# %cd yolov7
# Out:
# c:\Users\wmp91\Desktop\졸작\GRIK\test\Test_Yolov7-tiny_Version\yolov7
# fatal: destination path 'yolov7' already exists and is not an empty directory.
# C:\Users\wmp91\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
## 패키지 설치
# !pip3 install -r requirements.txt

# %% [markdown]
# ### 데이터 옮기기

# %%
import os
print(os.path.realpath('.'))
# Out:
# C:\Users\wmp91\Desktop\졸작\GRIK\test\Test_Yolov7-tiny_Version\yolov7

# %%
import platform
if(platform.system() == 'Windows'): # Windows
    import shutil
    file_name = "../GRIKDataset.zip"
    output_dir = "data/"
    format = "zip"
    shutil.unpack_archive(file_name, output_dir, format)
else: # macOS, Linux
    # !pwd
    # !unzip -uq "../GRIKDataset.zip" -d "data/"

# %% [markdown]
# ### 가중치 파일 받기

# %%
import sys
import subprocess

if(platform.system() == 'Windows'): # Windows
    print(os.path.realpath('.'))
else: # macOS, Linux
    # !pwd

try:
	import wget
except:
    # pip 모듈 업그레이드
    subprocess.check_call([sys.executable,'-m', 'pip', 'install', '--upgrade', 'pip'])
    # 에러 발생한 모듈 설치
    subprocess.check_call([sys.executable,'-m', 'pip', 'install', '--upgrade', 'wget'])
    import wget

select_model = input("어떤 모델로 학습할까요? 1: yolov7  2: yolov7-tiny  >")
if select_model == '1':
    wget.download("https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt")
elif select_model == '2':
    wget.download("https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-tiny.pt")
else:
    print("잘못된 입력입니다.")
    sys.exit(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys
#       2 import subprocess
# ----> 4 if(platform.system() == 'Windows'): # Windows
#       5     print(os.path.realpath('.'))
#       6 else: # macOS, Linux
#
# NameError: name 'platform' is not defined

# %% [markdown]
# ## 학습 시작

# %% [markdown]
# ### YOLOv7

# %%
# 현재 경로 확인
if(platform.system() == 'Windows'): # Windows
    print(os.path.realpath('.'))
else: # macOS, Linux
    # !pwd
    
# 학습 시작
if(torch.backends.mps.is_available()):
	# !python train.py --workers 1 --device mps --batch-size 16 --epochs 400 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --name yolov7-custom --weights yolov7.pt
elif(torch.cuda.is_available()):
    # !python train.py --workers 1 --device 0 --batch-size 16 --epochs 400 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --name yolov7-custom --weights yolov7.pt
else:
    # !python train.py --workers 1 --batch-size 16 --epochs 400 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --name yolov7-custom --weights yolov7.pt
# Out:
# C:\Users\wmp91\Desktop\졸작\GRIK\Test\Test_Yolov7-tiny_Version\yolov7
# ^C
# YOLOR  v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7.yaml', data='data/GRIKDataset/data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=100, batch_size=8, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=1, project='runs/train', entity=None, name='yolov7-custom', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs\\train\\yolov7-custom2', total_batch_size=8)
# ...

# %% [markdown]
# ### YOLOv7-tiny

# %%
# 현재 경로 확인
if(platform.system() == 'Windows'): # Windows
    print(os.path.realpath('.'))
else: # macOS, Linux
    # !pwd
    
# 학습 시작
if(torch.backends.mps.is_available()):
	# !python train.py --workers 1 --device mps --batch-size 16 --epochs 400 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --name yolov7-tiny-custom --weights yolov7-tiny.pt --freeze 28
elif(torch.cuda.is_available()):
    # !python train.py --workers 1 --device 0 --batch-size 16 --epochs 400 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --name yolov7-tiny-custom --weights yolov7-tiny.pt --freeze 28
else:
    # !python train.py --workers 1 --batch-size 16 --epochs 400 --img 640 640 --data data/GRIKDataset/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-tiny-custom.yaml --name yolov7-tiny-custom --weights yolov7-tiny.pt --freeze 28
# Out:
# C:\Users\wmp91\Desktop\졸작\GRIK\test\Test_Yolov7-tiny_Version\yolov7
# freezing model.0.conv.weight
# freezing model.0.bn.weight
# freezing model.0.bn.bias
# freezing model.1.conv.weight
# freezing model.1.bn.weight
# freezing model.1.bn.bias
# freezing model.2.conv.weight
# freezing model.2.bn.weight
# freezing model.2.bn.bias
# freezing model.3.conv.weight
# freezing model.3.bn.weight
# freezing model.3.bn.bias
# freezing model.4.conv.weight
# freezing model.4.bn.weight
# freezing model.4.bn.bias
# freezing model.5.conv.weight
# freezing model.5.bn.weight
# freezing model.5.bn.bias
# freezing model.7.conv.weight
# freezing model.7.bn.weight
# freezing model.7.bn.bias
# freezing model.9.conv.weight
# freezing model.9.bn.weight
# freezing model.9.bn.bias
# freezing model.10.conv.weight
# freezing model.10.bn.weight
# freezing model.10.bn.bias
# freezing model.11.conv.weight
# freezing model.11.bn.weight
# freezing model.11.bn.bias
# freezing model.12.conv.weight
# ...

# %% [markdown]
# ## 테스트

# %% [markdown]
# ### YOLOv7

# %%
if(torch.backends.mps.is_available()):
	# !python detect.py --weights ./runs/train/yolov7-custom/weights/best.pt --device mps --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
elif(torch.cuda.is_available()):
    # !python detect.py --weights ./runs/train/yolov7-custom/weights/best.pt --device 0 --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
else:
    # !python detect.py --weights ./runs/train/yolov7-custom/weights/best.pt --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
# Out:
# Namespace(weights=['./runs/train/yolov7-custom/weights/best.pt'], source='../Test_IMG/test05.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='0', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 3 panseos, Done. (10.5ms) Inference, (76.1ms) NMS
#  The image with the result is saved in: runs\detect\exp\test05.jpg
# Done. (0.385s)
# YOLOR  v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
#
# ...

# %% [markdown]
# ### YOLOv7-tiny

# %%
if(torch.backends.mps.is_available()):
	# !python detect.py --weights ./runs/train/yolov7-tiny-custom3/weights/best.pt --device mps --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
elif(torch.cuda.is_available()):
    # !python detect.py --weights ./runs/train/yolov7-tiny-custom3/weights/best.pt --device 0 --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
else:
    # !python detect.py --weights ./runs/train/yolov7-tiny-custom3/weights/best.pt --conf 0.25 --img-size 640 --source ../Test_IMG/test05.jpg
# Out:
# Namespace(weights=['./runs/train/yolov7-tiny-custom2/weights/best.pt'], source='../Test_IMG/test05.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='0', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 3 panseos, Done. (4.6ms) Inference, (62.7ms) NMS
#  The image with the result is saved in: runs\detect\exp6\test05.jpg
# Done. (0.284s)
# YOLOR  v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
#
# c:\Users\wmp91\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3550.)
# ...
