# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /content

# %%
def imshow(image):
  plt.imshow(image)
  plt.axis('off')
  plt.show()

# %%
printed = cv2.imread('/content/drive/MyDrive/iapLab/final/pixelextract/printed.jpg')
handwritten = cv2.imread('/content/drive/MyDrive/iapLab/final/pixelextract/handwritten.jpg')

pr = cv2.cvtColor(printed, cv2.COLOR_BGR2RGB)
hw = cv2.cvtColor(handwritten, cv2.COLOR_BGR2RGB)

imshow(pr)
imshow(hw)

# %%
print(pr.shape)
print(hw.shape)
# Out:
# (720, 1280, 3)
# (720, 1280, 3)

# %%
h, w, c = pr.shape

diff = np.abs(hw.astype(np.int32) - pr.astype(np.int32))

# mask = np.max(diff, axis=2) <= 10
# hw[~mask] = [255,255,255]

mask = np.all(hw==pr, axis=2)
# mask = np.repeat(mask[:,:, np.newaxis], 3, axis=2)
hw[mask] = [255,255,255]
# print(mask.shape)

# extract = np.zeros(hw.shape, dtype=np.int32)
# extract[:] = (255,255,255)

extract = hw[~mask]
extract = cv2.cvtColor(extract, cv2.COLOR_BGR2RGB)
extract = cv2.resize(extract, (1280,720))

print(extract.shape)

# imshow(hw)
imshow(extract)
# Out:
# (720, 1280, 3)

# %%
extract.shape
# Out:
# (919163, 3)
